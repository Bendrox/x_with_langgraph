# %%
import time

# %%
def taches_synchrones(duree: int):
    print("Début opération")
    time.sleep(duree)
    print("Fin operation")

# %%
taches_synchrones(3)
# Out:
# Début opération
# Fin operation
