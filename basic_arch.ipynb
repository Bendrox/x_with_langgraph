# %%
from typing_extensions import TypedDict, Literal, Annotated, Concatenate, Self, NotRequired
from typing_extensions import Final , TypeAlias, TypeGuard, ParamSpec
import random
from typing import Literal

# %%
# def states: 
class State(TypedDict): 
	graph_state :str

# %%
state1 : State = {'graph_state': ''}
state1
# Out:
# {'graph_state': ''}

# %%
# def nodes 

def node_1(state):
    print("-Node 1-")
    return {state["graph_state"] : state['graph_state'] + "I am"}

def node_2(state):
    print("-Node 2-")
    return {state["graph_state"] : state['graph_state'] + " exited "}

def node_3(state):
    return {state["graph_state"] : state['graph_state'] + " about AI "}

# %%
# Edges (connectinng nodes)

def decide_mood(state) -> Literal["node_2", "node_3"]:
    
    user_input=state['graph_state']
    
    if random.random() < 0.5 :
        return "node_2"
    
    return "node_3"

# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START, END

# build graph
builder= StateGraph(State)
builder.add_node("node_1", node_1)
builder.add_node("node_2", node_2)
builder.add_node("node_3", node_3)

# %%
# logic
